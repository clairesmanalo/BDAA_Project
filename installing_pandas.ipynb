# %% [markdown]
# pip install pandas numpy matplotlib seaborn scikit-learn scipy statsmodels
# pip install --upgrade pip

# %%
import sys
import subprocess

# List of packages to install
packages = [
    "pandas",           # Data manipulation (Excel-like tables)
    "numpy",            # Linear Algebra and arrays
    "matplotlib",       # Basic plotting
    "folium",           # Interactive maps
    "seaborn",          # Advanced statistical visualization
    "scikit-learn",     # Predictive modeling (Machine Learning)
    "scipy",            # Advanced scientific computing (integrals, diff eq)
    "statsmodels",      # Statistical testing (proving significance)
]

def install(package):
    print(f"Installing {package}...")
    try:
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])
        print(f"Successfully installed {package}")
    except subprocess.CalledProcessError:
        print(f"Failed to install {package}")

if __name__ == "__main__":
    print("Starting Data Science Suite Installation...")
    # Upgrade pip first just in case
    subprocess.check_call([sys.executable, "-m", "pip", "install", "--upgrade", "pip"])
    
    for p in packages:
        install(p)
        
    print("\nAll done! You are ready to analyze.")
# Out:
# Starting Data Science Suite Installation...
# ...
# Installing pandas...
# ...
# Installing numpy...
# ...
# Installing matplotlib...
# ...
# Installing folium...
# ...
# Installing seaborn...
# ...
# Installing scikit-learn...
# ...
# Installing scipy...
# ...
# Installing statsmodels...
# ...
#
# All done! You are ready to analyze.

# %% [markdown]
# pip list | grep -E "pandas|numpy|matplotlib|seaborn|plotly|folium|scipy|scikit-learn"

# %% [markdown]
# Creating a virtual environment
# Plug this into your terminal
# python -m venv name_of_Environment
#
#
# MAC activate
# source name_of_Environment/bin/activate
#
# Windows activate
# venv\Scripts\activate.bat
#
# TO DEACTIVATE
# deactivate

# %% [markdown]
# Link for installing medium page
#
# https://medium.com/@ohiostatebdaa/how-to-install-pandas-0fbc06904ef2

# %% [markdown]
# Here is the pandas API description
# https://pandas.pydata.org/docs/reference/io.html#excel
